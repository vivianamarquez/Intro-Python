# %% [markdown]
# ## Exercise 1
#
# Complete the code below to write a `for` loop that sums all the numbers in a list.
#
# For example, if `numbers = [1, 2, 3]`, then the total sum will be `6`.

# %%
numbers = [3, 6, 8, 7, 1, 2]

# %%
print('Sum of the numbers:', total)

# %% [markdown]
# ## Exercise 2
#
# Create a function that receives a number and returns whether the number is even or odd.

# %%
def

# %% [markdown]
# # Exercise 3
#
# Do a quick Google search and find a Python library that catches your interest. Use it below:
